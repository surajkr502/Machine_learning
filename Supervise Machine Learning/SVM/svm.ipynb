# %%
# conda install -c conda-forge xgboost

# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.preprocessing import LabelEncoder 
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from xgboost import 
import time
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder
import matplotlib.pyplot as plt 
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.svm import SVC
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 10
#       8 from sklearn.linear_model import LogisticRegression
#       9 from sklearn.neighbors import KNeighborsClassifier
# ---> 10 from xgboost import KNeighborsClassifier
#      11 import time
#      12 from sklearn.model_selection import GridSearchCV
#
# ImportError: cannot import name 'KNeighborsClassifier' from 'xgboost' (C:\Users\sawsu\AppData\Roaming\Python\Python313\site-packages\xgboost\__init__.py)

# %%
dt=pd.read_csv('D:/Ad_py_lib.csv/ml_csv/1762150821340_multilogistic.csv')

# %%
dt
# Out:
#     CGPA  SCORE  PLACED
# 0    7.2    6.3       1
# 1    8.4    8.1       1
# 2    7.7    6.2       0
# 3    7.3    5.1       0
# 4    9.2    8.4       1
# 5    7.3    4.4       0
# 6    6.5    8.5       0
# 7    8.1    7.8       1
# 8    8.3    5.9       1
# 9    9.9    7.9       1
# 10   6.6    7.1       0
# 11   7.5    7.8       1
# 12   8.3    4.5       0
# 13   8.8    5.3       0
# 14   9.7    4.0       0
# 15   7.9    8.3       1
# 16   5.8    6.3       0
# 17   7.7    7.0       1
# 18   6.9    8.3       1
# 19   6.9    8.5       1
# 20   6.8    7.5       1
# 21   9.2    4.9       0
# 22   9.4    3.9       0
# 23   9.6    6.9       1
# 24   9.9    8.9       1

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x=dt['CGPA'],y=dt['SCORE'],data=dt,hue=dt['PLACED'])
# Out:
# <Axes: xlabel='CGPA', ylabel='SCORE'>

# %%
dt.columns
# Out:
# Index(['CGPA', 'SCORE', 'PLACED'], dtype='object')

# %%
X=dt[['CGPA','SCORE']]
y=dt['PLACED']

# %%
X
# Out:
#     CGPA  SCORE
# 0    7.2    6.3
# 1    8.4    8.1
# 2    7.7    6.2
# 3    7.3    5.1
# 4    9.2    8.4
# 5    7.3    4.4
# 6    6.5    8.5
# 7    8.1    7.8
# 8    8.3    5.9
# 9    9.9    7.9
# 10   6.6    7.1
# 11   7.5    7.8
# 12   8.3    4.5
# 13   8.8    5.3
# 14   9.7    4.0
# 15   7.9    8.3
# 16   5.8    6.3
# 17   7.7    7.0
# 18   6.9    8.3
# 19   6.9    8.5
# 20   6.8    7.5
# 21   9.2    4.9
# 22   9.4    3.9
# 23   9.6    6.9
# 24   9.9    8.9

# %%
y
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    1
# 12    0
# 13    0
# 14    0
# 15    1
# 16    0
# 17    1
# 18    1
# 19    1
# 20    1
# 21    0
# 22    0
# 23    1
# 24    1
# Name: PLACED, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=20)

# %%
sv=SVC(kernel='rbf')

# %%
model=sv.fit(X_train,y_train)

# %%
model
# Out:
# SVC()

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
model.score(X_train,y_train)
# Out:
# 0.85

# %%
plot_decision_regions(X_train.to_numpy(),y_train.to_numpy(),clf=model)
# Out:
# <Axes: >

# %%
import joblib
joblib.dump
# Out:
# <function joblib.numpy_pickle.dump(value, filename, compress=0, protocol=None, cache_size=None)>

# %%
import pandas as pd 
import numpy as np 
from xgboost import XGBClassifier,plot_tree
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
df={'Dosage':[2,8,12,18],'Gender':['M','F','M','F']}

# %%
lb=LabelEncoder() 
df['Gender']=lb.fit_transform(df['Gender'])
# dataset 
X=df.drop(columns=['Effect']).values
y=df['Effect'].values
y
df['Gender']
x 
y

# %%
model=XGBClassifier()
model.fit(X,y)

# %%
model.predict([[8,0]])

# %%
hyper parameter optimixzation
params={
    'learning_rate':[0.05,],
    'max_depth':[3,5,6,2,8,9]
}

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV
Xgnew=XGBClassifier

# %%
gd=GridSearchCV(Xgnew,param_grid=params,cv=2)

# %%
Gd.fit(X,y)

# %%
Gd.best_params_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Gd.best_params_
#
# NameError: name 'Gd' is not defined
