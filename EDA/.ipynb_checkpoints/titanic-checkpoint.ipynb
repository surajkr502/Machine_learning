# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings 

warnings.filterwarnings('ignore')

# %%
dt=pd.read_csv("train.csv")

# %% [markdown]
# ## 1. How big is the data?

# %%
dt.shape
# Out:
# (891, 12)

# %% [markdown]
# ## 2. How does the data look like?

# %%
dt.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dt.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 608          609         1       2
# 736          737         0       3
# 166          167         1       1
# 141          142         1       3
# 822          823         0       1
# 879          880         1       1
# 331          332         0       1
# 282          283         0       3
# 599          600         1       1
# 89            90         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 608  Laroche, Mrs. Joseph (Juliette Marie Louise La...  female  22.0      1
# 736            Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0      1
# 166             Chibnall, Mrs. (Edith Martha Bowerman)  female   NaN      0
# 141                           Nysten, Miss. Anna Sofia  female  22.0      0
# 822                    Reuchlin, Jonkheer. John George    male  38.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# ...

# %% [markdown]
# ## 3. What is the data type of columns?

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## 4. Are there any missing values?

# %%
dt.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 5. How does data look like mathematically?

# %%
dt.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## 6. Are there is any duplicate values?

# %%
dt.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 7. How does the correlation between columns?

# %%
dt.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dt.corr(numeric_only=True)['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %% [markdown]
# # EDA(Univariante)

# %% [markdown]
# ## Categorical data

# %% [markdown]
# ## a. Countplot

# %%
sns.countplot(x='Survived',data=dt)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
dt['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
dt['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x='Pclass',data=dt)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
dt['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='Embarked',data=dt)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
dt['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex',data=dt)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
dt['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
dt['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
sns.countplot(x='SibSp',data=dt)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
dt['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
sns.countplot(x='Parch',data=dt)
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %% [markdown]
# ## b. Pie Chart

# %%
dt['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
dt['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
plt.hist(dt['Age'],bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(dt['Fare'],bins=5)
# Out:
# (array([838.,  33.,  17.,   0.,   3.]),
#  array([  0.     , 102.46584, 204.93168, 307.39752, 409.86336, 512.3292 ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ## b. Displot

# %%
sns.displot(dt['Age'])

# %% [markdown]
# ## c. Boxplot

# %%
sns.boxplot(dt['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %% [markdown]
# # Bivariate and MultiVariate Analysis.

# %% [markdown]
# ## 1. Scatterplot(Numerical-Numerical)

# %%
sns.scatterplot(x='Fare',y='PassengerId',data=dt,hue='Sex',style='SibSp',size='Pclass')
# Out:
# <Axes: xlabel='Fare', ylabel='PassengerId'>

# %% [markdown]
# ## 2. Barplot(Numerical-Categorical)

# %%
dt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot(x='Pclass',y='Age',data=dt,hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ## 3. BoxPlot(Numerical-Categorical)

# %%
sns.boxplot(y='Age',x='Sex',data=dt,hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ## 4. HistPlot(Numerical-Categorical)

# %%
# sns.histplot(data=dt,x='Age',hue='Survived',kde=True)
# sns.histplot(data=dt,x='Age',hue='Survived',kde=False)
sns.histplot(data=dt,x='Age',hue='Survived',kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## 5. Heatmap(Categorical-Categorical)

# %%
sns.heatmap(pd.crosstab(dt['Pclass'],dt['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(dt.groupby('Sex').mean(numeric_only=True)['Survived'])
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# ## 6. ClusterMap(Categorical-Categorical)

# %%
pd.crosstab(dt['Sex'],dt['Embarked'])
# Out:
# Embarked   C   Q    S
# Sex
# female    73  36  203
# male      95  41  441

# %%
sns.clustermap(pd.crosstab(dt['Sex'],dt['Embarked']))

# %%
sns.pairplot(dt,hue='Survived')

# %% [markdown]
# ## 7. Lineplot(Numerical-Numerical):-Mainly use when data varied with time.

# %%
new=dt.groupby('Parch').sum(numeric_only=True).reset_index()

# %%
sns.lineplot(new['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
# pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport
import pandas as pd

df = pd.read_csv("heart (1).csv")

profile = ProfileReport(df)
profile.to_file("heart.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
