# %%
# pip install kaggle

# %%
import numpy as np 
import pandas as pd

# %%
pd.read_csv('hotel_cancellation_data.csv')
# Out:
#                                 booking_id   hotel_type  lead_time_days  \
# 0     faad4210-3331-4812-a804-fe78f5150368  ResortHotel             342
# 1     b4a3d2f4-9a21-46e4-9a99-0faaca209fd2  ResortHotel             137
# 2     de911a9d-6ef3-4c22-adf1-d25fd013d297  ResortHotel             265
# 3     b3fadaee-c4b1-40ab-abdf-3f079faf71f2  ResortHotel             102
# 4     7a2efff7-7973-43f0-b54a-46b848f4d8b7    CityHotel              43
# ...                                    ...          ...             ...
# 1495  de158dd9-5188-4d35-adf2-d92d524225dd    CityHotel              73
# 1496  a0986378-31d0-455a-9742-d50dbbc7e5cc  ResortHotel             270
# 1497  abb49a30-a34f-49e9-abdb-734391d26687  ResortHotel             225
# 1498  e3e65a4b-b037-4e0b-9c12-915127389104  ResortHotel              20
# 1499  b97ca1da-2f45-4bee-a75c-7d1143ed278d    CityHotel             142
#
#       arrival_month  arrival_day  stays_weekend_nights  stays_week_nights  \
# ...
