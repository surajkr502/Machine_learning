# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
dt=pd.read_csv("heart (1).csv")

# %%
dt.shape
# Out:
# (918, 12)

# %%
dt.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
dt.sample(5)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 882   56   F           ATA        140          294          0        LVH
# 84    56   M           ASY        150          213          1     Normal
# 646   66   M           ASY        160          228          0        LVH
# 784   65   M            TA        138          282          1        LVH
# 34    43   F           ATA        150          186          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 882    153              N      1.3     Flat             0
# 84     125              Y      1.0     Flat             1
# 646    138              N      2.3       Up             0
# 784    174              N      1.4     Flat             1
# 34     154              N      0.0       Up             0

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
dt.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
dt.describe().T
# Out:
#               count        mean         std   min     25%    50%    75%    max
# Age           918.0   53.510893    9.432617  28.0   47.00   54.0   60.0   77.0
# RestingBP     918.0  132.396514   18.514154   0.0  120.00  130.0  140.0  200.0
# Cholesterol   918.0  198.799564  109.384145   0.0  173.25  223.0  267.0  603.0
# FastingBS     918.0    0.233115    0.423046   0.0    0.00    0.0    0.0    1.0
# MaxHR         918.0  136.809368   25.460334  60.0  120.00  138.0  156.0  202.0
# Oldpeak       918.0    0.887364    1.066570  -2.6    0.00    0.6    1.5    6.2
# HeartDisease  918.0    0.553377    0.497414   0.0    0.00    1.0    1.0    1.0

# %%
dt.corr(numeric_only=True)['HeartDisease']
# Out:
# Age             0.282039
# RestingBP       0.107589
# Cholesterol    -0.232741
# FastingBS       0.267291
# MaxHR          -0.400421
# Oldpeak         0.403951
# HeartDisease    1.000000
# Name: HeartDisease, dtype: float64

# %%
sns.countplot(x='HeartDisease',data=dt)
plt.title('Heart_disease')
# Out:
# Text(0.5, 1.0, 'Heart_disease')

# %%
dt['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
sns.countplot(x='FastingBS',data=dt)
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
dt['FastingBS'].value_counts()
# Out:
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64

# %%
sns.countplot(x='ChestPainType',data=dt)
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
dt['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex',data=dt)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
dt['Sex'].value_counts()
# Out:
# Sex
# M    725
# F    193
# Name: count, dtype: int64

# %%
sns.countplot(x='RestingECG',data=dt)
# Out:
# <Axes: xlabel='RestingECG', ylabel='count'>

# %%
dt['RestingECG'].value_counts()
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
sns.countplot(x='FastingBS',data=dt)
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
dt['FastingBS'].value_counts()
# Out:
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64

# %%
sns.countplot(x='ExerciseAngina',data=dt)
# Out:
# <Axes: xlabel='ExerciseAngina', ylabel='count'>

# %%
dt['ExerciseAngina'].value_counts()
# Out:
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64

# %%
dt['ST_Slope'].value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
sns.countplot(x='ST_Slope',data=dt)
# Out:
# <Axes: xlabel='ST_Slope', ylabel='count'>

# %%
dt['HeartDisease'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
dt['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(dt['Age'],bins=10)
# Out:
# (array([ 12.,  37.,  86., 104., 148., 201., 175., 101.,  39.,  15.]),
#  array([28. , 32.9, 37.8, 42.7, 47.6, 52.5, 57.4, 62.3, 67.2, 72.1, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(dt['Age'])

# %%
sns.boxplot(dt['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.scatterplot(x='Age',y='Cholesterol',data=dt,hue='Sex',style='ExerciseAngina',size='ST_Slope')
# Out:
# <Axes: xlabel='Age', ylabel='Cholesterol'>
