# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('species',axis=1)
y=df['species']

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
 X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
model_06_knn=KNeighborsClassifier(n_neighbors=13)
model_06_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_06_knn.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC
model_06_svm=SVC(C=30,kernel='rbf',gamma='auto')

# %%
model_06_svm.fit(X_train,y_train)
# Out:
# SVC(C=30, gamma='auto')

# %%
model_06_svm.score(X_test,y_test)
# Out:
# 0.98

# %% [markdown]
# #### Now lets use the grid search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier=GridSearchCV((model_06_svm),
                        {
                            'C':[1,10,20,25,30], 
                            'kernel':['rbf','linear'], 
                        },cv=5,return_train_score=False)

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(C=30, gamma='auto'),
#              param_grid={'C': [1, 10, 20, 25, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00214434, 0.00144954, 0.00141592, 0.00134969, 0.00138698,
#         0.00124736, 0.00131078, 0.00251913, 0.00176558, 0.00243535]),
#  'std_fit_time': array([3.42462508e-04, 7.65084292e-05, 3.97229680e-05, 5.47048819e-05,
#         1.14618462e-04, 3.41854000e-05, 2.01637289e-05, 2.10680301e-03,
#         6.66597397e-04, 2.17259637e-03]),
#  'mean_score_time': array([0.00150509, 0.00112524, 0.00106754, 0.00100646, 0.00106115,
#         0.00097342, 0.00102654, 0.00218577, 0.00113783, 0.00151095]),
#  'std_score_time': array([2.98885905e-04, 6.07271544e-05, 2.33058765e-05, 2.98522912e-05,
#         2.91352576e-05, 1.13467207e-05, 2.79658387e-05, 1.49517826e-03,
#         2.25085555e-04, 9.76226544e-04]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 25, 25, 30, 30],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=999999),
# ...

# %%
results=pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.002144      0.000342         0.001505        0.000299        1
# 1       0.001450      0.000077         0.001125        0.000061        1
# 2       0.001416      0.000040         0.001068        0.000023       10
# 3       0.001350      0.000055         0.001006        0.000030       10
# 4       0.001387      0.000115         0.001061        0.000029       20
# 5       0.001247      0.000034         0.000973        0.000011       20
# 6       0.001311      0.000020         0.001027        0.000028       25
# 7       0.002519      0.002107         0.002186        0.001495       25
# 8       0.001766      0.000667         0.001138        0.000225       30
# 9       0.002435      0.002173         0.001511        0.000976       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# ...

# %%
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       25          rbf         0.966667
# 7       25       linear         0.960000
# 8       30          rbf         0.960000
# 9       30       linear         0.960000

# %%
classifier2=

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier_r=RandomizedSearchCV((model_06_svm),{
    'C':[1,10,20,30],
    'kernel':['rbf','linear'],},n_iter=4,cv=5,return_train_score=False)

# %%
classifier_r.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(C=30, gamma='auto'), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['rbf', 'linear']})

# %%
results_r=pd.DataFrame(classifier_r.cv_results_)

# %%
results_r
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.013255      0.016783         0.004507        0.002854          rbf
# 1       0.002542      0.000525         0.002672        0.000919          rbf
# 2       0.002139      0.000505         0.001577        0.000287       linear
# 3       0.002277      0.000364         0.001947        0.000728       linear
#
#    param_C                         params  split0_test_score  \
# 0       10     {'kernel': 'rbf', 'C': 10}           0.966667
# 1        1      {'kernel': 'rbf', 'C': 1}           0.966667
# 2       10  {'kernel': 'linear', 'C': 10}           1.000000
# 3       30  {'kernel': 'linear', 'C': 30}           1.000000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# ...

# %%
results_r[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0       10          rbf         0.980000
# 1        1          rbf         0.980000
# 2       10       linear         0.973333
# 3       30       linear         0.960000

# %% [markdown]
# #### Stacking

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
from sklearn.svm import SVC
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
X1=df.drop('species',axis=1)
y1=df['species']

# %%
le=LabelEncoder()
y_encoded=le.fit_transform(y)

# %%
X_test,X_train,y_test,y_train=train_test_split(X,y_encoded,test_size=0.2,random_state=42,
                                             stratify=y_encoded )

# %%
base_learners=[
    ('dt',DecisionTreeClassifier(random_state=42)),
    ('svc',SVC(probability=True,kernel='rbf',random_state=42)), 
    ('lr',LogisticRegression(max_iter=1000))
]

# %%
mata_learner=LogisticRegression(max_iter=1000)

# %%
stacking_clf=StackingClassifier(
    estimators=base_learners,
    final_estimator=mata_learner,cv=5)

# %%
stacking_clf.fit(X_train,y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('dt', DecisionTreeClassifier(random_state=42)),
#                                ('svc', SVC(probability=True, random_state=42)),
#                                ('lr', LogisticRegression(max_iter=1000))],
#                    final_estimator=LogisticRegression(max_iter=1000))

# %%
y_pred=stacking_clf.predict(X_test)

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9583333333333334

# %% [markdown]
# #### Bagging

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(
    n_estimators=100, 
    max_depth=None,
    random_state=42
)

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred1=rf_model.predict(X_test)

# %%
accuracy2=accuracy_score(y_test,y_pred1)

# %%
accuracy2
# Out:
# 0.9583333333333334
